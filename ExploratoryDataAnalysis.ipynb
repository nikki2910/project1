# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_csv("Desktop/covid19_India.csv")

# %%
df.describe()
# Out:
#         total_cases         active    discharged          death  active_ratio  \
# count  3.600000e+01      36.000000  3.600000e+01      36.000000     36.000000
# mean   9.114124e+05   10505.027778  8.887123e+05   12195.000000      1.255278
# std    1.334291e+06   37159.139184  1.290595e+06   23546.148094      2.661486
# min    7.566000e+03       4.000000  7.431000e+03       4.000000      0.010000
# 25%    7.315325e+04     145.000000  7.021225e+04     809.750000      0.047500
# 50%    4.686465e+05     839.000000  4.597350e+05    5396.000000      0.535000
# 75%    1.005276e+06    6034.500000  9.911718e+05   13630.500000      0.945000
# max    6.464876e+06  219441.000000  6.272800e+06  137313.000000     15.030000
#
#        discharged_ratio  death_ratio
# count         36.000000    36.000000
# mean          97.478611     1.266111
# std            2.556711     0.563541
# min           84.600000     0.040000
# 25%           97.632500     0.955000
# 50%           98.225000     1.300000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State/UTs            36 non-null     object
#  1   Total Cases          36 non-null     int64
#  2   Active               36 non-null     int64
#  3   Discharged           36 non-null     int64
#  4   Deaths               36 non-null     int64
#  5   Active Ratio (%)     36 non-null     float64
#  6   Discharge Ratio (%)  36 non-null     float64
#  7   Death Ratio (%)      36 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 2.4+ KB

# %%
print(f'''dataframe shape: Rows: {df.shape[0]}, Columns: {df.shape[1]}
dataframe  null values: {df.isnull().sum().sum()}
dataframe columns name: \n
{df.columns.values}''')
# Out:
# dataframe shape: Rows: 36, Columns: 8
# dataframe  null values: 0
# dataframe columns name:
#
# ['State/UTs' 'Total Cases' 'Active' 'Discharged' 'Deaths'
#  'Active Ratio (%)' 'Discharge Ratio (%)' 'Death Ratio (%)']

# %%
df.head(10)
# Out:
#                                   State/UTs  Total Cases  Active  Discharged  \
# 0                       Andaman and Nicobar         7566       6        7431
# 1                            Andhra Pradesh      2014116   14693     1985566
# 2                         Arunachal Pradesh        53031     863       51908
# 3                                     Assam       589426    6901      576865
# 4                                     Bihar       725708     100      715955
# 5                                Chandigarh        65105      40       64252
# 6                              Chhattisgarh      1004451     412      990484
# 7  Dadra and Nagar Haveli and Daman and Diu        10663       4       10655
# 8                                     Delhi      1437764     349     1412333
# 9                                       Goa       173955     877      169877
#
#    Deaths  Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# ...

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.barplot(x='State/UTs',y='Discharged',data=df)
# Out:
# <AxesSubplot:xlabel='State/UTs', ylabel='Discharged'>

# %%
df.columns = ['state','total_cases','active','discharged','death','active_ratio','discharged_ratio','death_ratio']
df
# Out:
#                                        state  total_cases  active  discharged  \
# 0                        Andaman and Nicobar         7566       6        7431
# 1                             Andhra Pradesh      2014116   14693     1985566
# 2                          Arunachal Pradesh        53031     863       51908
# 3                                      Assam       589426    6901      576865
# 4                                      Bihar       725708     100      715955
# 5                                 Chandigarh        65105      40       64252
# 6                               Chhattisgarh      1004451     412      990484
# 7   Dadra and Nagar Haveli and Daman and Diu        10663       4       10655
# 8                                      Delhi      1437764     349     1412333
# 9                                        Goa       173955     877      169877
# 10                                   Gujarat       825422     150      815191
# ...

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df[['active_ratio', 'discharged_ratio', 'death_ratio']])

# %%
import altair as alt

alt.Chart(df).mark_circle(size=100).encode(
    x='active',
    y='total_cases',
    color='state',
    tooltip=['total_cases', 'active', 'discharged','death','state']
).interactive()
# Out:
# alt.Chart(...)
